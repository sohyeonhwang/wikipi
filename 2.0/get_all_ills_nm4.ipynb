# %%
from bs4 import BeautifulSoup
import requests
import re, os, csv
import wikifunctions_s as wfs
import pandas as pd
import time
import json
from collections import Counter

# %%
langs_10 = ['en','fr','de','ja','es','ru','zh','it','pt','fa']
langs_5 = ['en','fr','de','ja','es']

# %% [markdown]
# Get all pages in the Wikipedia Project namespace per language edition

# %%
# %%script false --no-raise-error
# # getting the list of all pages in the wikipedia project namespace per language edition
# rule_dfs_dict = {}
# rule_dfs_list = []
#
# for l in langs_10:
#     _temp = wfs.get_all_pages_in_namespace(l)
#     rule_dfs_dict[l] = _temp
#     rule_dfs_list.append(_temp)
#     print('{} has {} pages with language links in the Wikipedia Project namespace'.format(l, len(_temp)))
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# # export each list as df -> tsv so that we don't have to get them all over again
# output_directory = 'nm4_all_list'
#
# if not os.path.isdir(output_directory):
#     os.mkdir(output_directory)
#
# for df in rule_dfs_list:
#     _lang = df.lang.values.tolist()[0]
#     path = './{}/{}.tsv'.format(output_directory,_lang)
#     df.to_csv(path,index=False,sep='\t')
# Out:
# Couldn't find program: 'false'

# %% [markdown]
# Get all the interlanguage links for the pages in the Wikipedia project namespace

# %%
# now load those dfs and get all the ILLs for the pages
rule_dfs_dict = {}
rule_dfs_list = []

for l in langs_10:
    path = './nm4_all_list/{}.tsv'.format(l)
    _df = pd.read_csv(path, sep='\t',header=0)
    rule_dfs_dict[l] = _df
    rule_dfs_list.append(_df)

# %%
output_directory = 'nm4_all_ills'

if not os.path.isdir(output_directory):
    os.mkdir(output_directory)

# %% [markdown]
# This block below takes like 100+ minutes to run. Strap in and work on something else.

# %%
# %%script false --no-raise-error
# interlanguage_links = {}
#
# # run through each language edition
# for lang in langs_10:#[1:]:
#     print(lang)
#     start = time.time()
#     interlanguage_links[lang] = {}
#     # get the list of pages
#     _df = rule_dfs_dict[lang]
#     rule_list = _df['title'].values.tolist()
#
#     # for each page
#     for rule in rule_list:
#         ill_dict = wfs.get_interlanguage_links(rule, endpoint=lang, redirects=1)
#         interlanguage_links[lang][rule] = {}
#         interlanguage_links[lang][rule]['count'] = len(list(ill_dict.keys()))
#         interlanguage_links[lang][rule]['langs'] = list(ill_dict.keys())
#         interlanguage_links[lang][rule]['links'] = ill_dict
#
#     # export the interlanguage_links[lang]
#     with open("./{}/ills_{}.json".format(output_directory,lang), "w") as outfile:
#         json.dump(interlanguage_links[lang], outfile)
#
#     end = time.time()
#     print("{}: {}".format(lang, end - start))
# Out:
# Couldn't find program: 'false'

# %% [markdown]
# ```
# fr
#     Wikipédia:Politique de confidentialité
#     {'interwiki': [{'title': 'meta:Privacy policy/fr', 'iw': 'meta'}], 'redirects': [{'from': 'Wikipédia:Politique de confidentialité', 'to': 'meta:Privacy policy/fr', 'tointerwiki': 'meta'}]}
# fr: 1433.1813595294952
# de: 405.3607313632965
# ja: 209.69620060920715
# es: 216.3900294303894
# ru: 274.83118629455566
# zh: 687.3477938175201
# it: 105.42117857933044
# pt: 516.9702491760254
# fa: 493.1874372959137
# ```

# %% [markdown]
# ```
# f = open("./{}/ills_en.json".format(output_directory))
# en_data = json.load(f)
# interlanguage_links['en'] = en_data
# print(interlanguage_links.keys())
# with open("./{}/ills_all.json".format(output_directory), "w") as outfile:
#     json.dump(interlanguage_links, outfile)
# ```

# %% [markdown]
# Filter through the pages in the Wikipedia Project namespace by the number of interlanguage links they have

# %%
# load up interlanguage_links
f = open("./{}/ills_all.json".format(output_directory))
interlanguage_links = json.load(f)

# %%
interlanguage_links.keys(), len(interlanguage_links.keys())
# Out:
# (dict_keys(['fr', 'de', 'ja', 'es', 'ru', 'zh', 'it', 'pt', 'fa', 'en']), 10)

# %%
#flatten interlanguage_links
_data = []

for lang in interlanguage_links:
    for rule in interlanguage_links[lang]:
        _count = interlanguage_links[lang][rule]['count']
        _langs = interlanguage_links[lang][rule]['langs']
        _links = interlanguage_links[lang][rule]['links']

        _data.append([lang,rule,_count,_langs,_links])

# %%
df = pd.DataFrame(_data,columns=['lang','title','ill_count','ill_langs','ill_links'])

# %%
len(df[df.ill_count > 10])
# Out:
# 9050

# %%
filtered_df = df.loc[df.ill_langs.map(set(langs_10).issubset)]
filtered_df = filtered_df.copy()
print(len(filtered_df))
filtered_df.head(3)
# Out:
# 1633
#    lang                               title  ill_count  \
# 11   fr  Wikipédia:Accueil de la communauté        201
# 13   fr         Wikipédia:Accueil principal        325
# 16   fr            Wikipédia:Administrateur        259
#
#                                             ill_langs  \
# 11  [fr, aa, ady, af, als, alt, ami, an, ang, ar, ...
# 13  [fr, aa, ab, ace, ady, af, ak, als, alt, am, a...
# 16  [fr, aa, ab, ace, ady, af, ak, als, am, an, an...
#
#                                             ill_links
# 11  {'fr': 'Wikipédia:Accueil de la communauté', '...
# 13  {'fr': 'Wikipédia:Accueil principal', 'aa': 'M...
# 16  {'fr': 'Wikipédia:Administrateur', 'aa': 'Wiki...

# %%
for lang in langs_10:
    print(lang,len(filtered_df[filtered_df.lang==lang]))
# Out:
# en 641
# fr 84
# de 114
# ja 97
# es 110
# ru 124
# zh 131
# it 78
# pt 128
# fa 126

# %%
len(
    filtered_df[filtered_df.ill_langs.map(set(['en']).issubset)]
)
# Out:
# 1633

# %%
def get_en_title(row):
    links = row.ill_links
    return links['en']

# %%
filtered_df['en_title'] = filtered_df.apply(get_en_title,axis=1)

# %%
# unfiltered rules, a set of project namespace pages that are clearly in the Wikipedia: space and have an ILL to all top ten language editions
unfiltered_rules = filtered_df.drop_duplicates(subset=['en_title'], keep='last').loc[filtered_df.en_title.str.contains('Wikipedia:')==True]

# %%
set(unfiltered_rules.lang.values.tolist())
# Out:
# {'de', 'en', 'es', 'it', 'pt'}

# %%
unfiltered_rules.sort_values(by='ill_count',ascending=False)
# Out:
#       lang                                            title  ill_count  \
# 27126   en                              Wikipedia:Wheel war        259
# 26939   en                           Wikipedia:Village pump        245
# 22017   en                                Wikipedia:Sandbox        203
# 18437   en                       Wikipedia:Community portal        201
# 18234   en                                   Wikipedia:Bots        181
# ...    ...                                              ...        ...
# 22592   en                          Wikipedia:Systemic bias         22
# 27877   en                  Wikipedia:WikiProject Economics         21
# 27521   en                 Wikipedia:WikiProject Basketball         19
# 28360   en                        Wikipedia:WikiProject Law         18
# 20510   en  Wikipedia:Manual of Style/Writing about fiction         18
#
#                                                ill_langs  \
# 27126  [en, aa, ab, ace, ady, af, ak, als, am, an, an...
# 26939  [en, ab, ace, ady, af, ak, als, alt, am, an, a...
# 22017  [en, aa, ace, ady, af, ak, als, an, ang, ar, a...
# 18437  [en, aa, ady, af, als, alt, ami, an, ang, ar, ...
# 18234  [en, ace, af, als, am, an, ang, ar, arc, ary, ...
# ...                                                  ...
# 22592  [en, ar, bg, bn, cs, de, eo, es, fa, fr, hr, i...
# 27877  [en, ar, de, es, fa, fi, fr, gl, it, ja, ko, m...
# 27521  [en, ar, ca, de, el, es, fa, fi, fr, it, ja, k...
# 28360  [en, de, es, fa, fr, id, it, ja, ko, lt, pl, p...
# 20510  [en, bg, de, es, fa, fi, fr, gl, hu, id, it, j...
#
#                                                ill_links  \
# 27126  {'en': 'Wikipedia:Administrators', 'aa': 'Wiki...
# 26939  {'en': 'Wikipedia:Village pump', 'ab': 'Авикип...
# 22017  {'en': 'Wikipedia:Sandbox', 'aa': 'Wikipedia:S...
# 18437  {'en': 'Wikipedia:Community portal', 'aa': 'Wi...
# 18234  {'en': 'Wikipedia:Bots', 'ace': 'Wikipedia:Bot...
# ...                                                  ...
# 22592  {'en': 'Wikipedia:Systemic bias', 'ar': 'ويكيب...
# 27877  {'en': 'Wikipedia:WikiProject Economics', 'ar'...
# 27521  {'en': 'Wikipedia:WikiProject Basketball', 'ar...
# 28360  {'en': 'Wikipedia:WikiProject Law', 'de': 'Wik...
# 20510  {'en': 'Wikipedia:Manual of Style/Writing abou...
#
#                                               en_title
# 27126                         Wikipedia:Administrators
# 26939                           Wikipedia:Village pump
# 22017                                Wikipedia:Sandbox
# 18437                       Wikipedia:Community portal
# 18234                                   Wikipedia:Bots
# ...                                                ...
# 22592                          Wikipedia:Systemic bias
# 27877                  Wikipedia:WikiProject Economics
# 27521                 Wikipedia:WikiProject Basketball
# 28360                        Wikipedia:WikiProject Law
# 20510  Wikipedia:Manual of Style/Writing about fiction
#
# [628 rows x 6 columns]

# %%
curated_rules_ills =  pd.read_csv("./../1.0/202104_rules_withillcolumns",sep='\t',header=0)
have_4_ills = curated_rules_ills.loc[curated_rules_ills.num_links ==5]
widely_shared_rules = have_4_ills.en.values.tolist()
len(widely_shared_rules)
# Out:
# 221

# %%
unfiltered_rules.loc[unfiltered_rules.en_title.isin(widely_shared_rules)].sort_values(by='ill_count',ascending=False)
# Out:
#       lang                                              title  ill_count  \
# 27126   en                                Wikipedia:Wheel war        259
# 18234   en                                     Wikipedia:Bots        181
# 21865   en              Wikipedia:Requests for bureaucratship        146
# 22561   en                                     Wikipedia:Stub        142
# 19284   en                             Wikipedia:Five pillars        132
# 18612   en                               Wikipedia:Copyrights        125
# 20842   en                    Wikipedia:Neutral point of view        121
# 27115   en                    Wikipedia:What Wikipedia is not        119
# 18265   en                              Wikipedia:Bureaucrats        115
# 18748   en                           Wikipedia:Disambiguation        113
# 20446   en                          Wikipedia:Manual of Style        112
# 21018   en                Wikipedia:Parenthetical referencing        106
# 17608   en                    Wikipedia:Articles for deletion        104
# 21293   en                  Wikipedia:Policies and guidelines        103
# 26858   en                                Wikipedia:Vandalism        101
# 17447   en                           Wikipedia:Article titles        100
# 20907   en                               Wikipedia:Notability         96
# 26734   en                               Wikipedia:User pages         94
# 26863   en                            Wikipedia:Verifiability         94
# 22460   en                               Wikipedia:Signatures         92
# 22581   en                             Wikipedia:Superprotect         89
# 18628   en             Wikipedia:Criteria for speedy deletion         88
# 22454   en                                 Wikipedia:Shortcut         86
# 22530   en                             Wikipedia:Sockpuppetry         83
# 18904   en                     Wikipedia:Eponymous categories         83
# 18188   en                                  Wikipedia:Be bold         83
# 20884   en                     Wikipedia:No original research         81
# 19670   en                         Wikipedia:Ignore all rules         81
# 18717   en                          Wikipedia:Deletion policy         80
# 19682   en                         Wikipedia:Image use policy         77
# 18218   en                          Wikipedia:Blocking policy         76
# 18062   en                        Wikipedia:Assume good faith         75
# 20888   en                      Wikipedia:No personal attacks         73
# 18918   en                                Wikipedia:Etiquette         70
# 18203   en            Wikipedia:Biographies of living persons         70
# 19715   en                 Wikipedia:Interface administrators         68
# 21288   en         Wikipedia:Please do not bite the newcomers         65
# 22932   en                        Wikipedia:Three-revert rule         64
# 20779   en                            Wikipedia:Moving a page         58
# 18937   en                           Wikipedia:External links         56
# 22820   en                   Wikipedia:Template documentation         55
# 20931   en                      Wikipedia:Notability (people)         53
# 18132   en                            Wikipedia:Autobiography         52
# 20732   en                                  Wikipedia:Merging         50
# 11496   it                                Wikipedia:Evasività         50
# 20508   en           Wikipedia:Manual of Style/Words to watch         50
# 19638   en                       Wikipedia:IP block exemption         49
# 18770   en  Wikipedia:Do not disrupt Wikipedia to illustra...         47
# 27047   en                  Wikipedia:Volunteer Response Team         42
# 22583   en                                 Wikipedia:Suppress         40
# 30449   en            Wikipedia:Wikipedia is not a dictionary         35
# 5644    es               Wikipedia:Esta página está protegida         30
# 20839   en                      Wikipedia:Navigation template         26
# 27050   en                           Wikipedia:Voting is evil         25
# 20510   en    Wikipedia:Manual of Style/Writing about fiction         18
#
#                                                ill_langs  \
# 27126  [en, aa, ab, ace, ady, af, ak, als, am, an, an...
# 18234  [en, ace, af, als, am, an, ang, ar, arc, ary, ...
# 21865  [en, ab, ady, an, ang, ar, ary, arz, as, av, a...
# 22561  [en, af, als, ang, ar, ary, arz, as, az, azb, ...
# 19284  [en, af, als, ang, ar, arz, as, ast, az, azb, ...
# 18612  [en, ab, af, als, an, ar, ary, arz, as, ast, a...
# 20842  [en, af, am, an, ar, ary, arz, as, ast, az, az...
# 27115  [en, af, als, ang, ar, ary, arz, as, ast, az, ...
# 18265  [en, af, ak, an, ar, ary, arz, ast, az, azb, b...
# 18748  [en, af, an, ar, arz, as, ast, az, azb, ba, ba...
# 20446  [en, af, am, an, ang, ar, arc, arz, as, av, aw...
# 21018  [en, af, am, ar, arz, as, azb, ba, be, be-x-ol...
# 17608  [en, ady, af, ak, ar, arz, av, az, azb, ba, ba...
# 21293  [en, af, am, ar, ary, arz, as, av, az, azb, ba...
# 26858  [en, af, als, ang, ar, arz, as, ast, az, azb, ...
# 17447  [en, ab, af, als, ar, arz, as, ast, az, azb, b...
# 20907  [en, af, am, an, ar, ary, arz, as, az, azb, ba...
# 26734  [en, af, ar, arz, as, az, azb, ba, be, be-x-ol...
# 26863  [en, af, ar, ary, arz, as, ast, az, azb, be, b...
# 22460  [en, als, ar, arz, as, az, azb, ba, bar, bg, b...
# 22581  [en, af, an, ang, ar, arz, as, az, azb, be-x-o...
# 18628  [en, ace, af, ar, arz, as, az, azb, ba, be, be...
# 22454  [en, af, als, ar, as, ast, az, azb, ba, be, be...
# 22530  [en, af, ar, arz, az, azb, ba, bar, be, be-x-o...
# 18904  [en, als, ar, arz, as, az, azb, ba, be, be-x-o...
# 18188  [en, af, als, ar, arz, as, av, az, azb, ba, ba...
# 20884  [en, af, als, ar, ary, arz, as, az, azb, ba, b...
# 19670  [en, als, ar, arz, as, ast, az, azb, be, be-x-...
# 18717  [en, af, ar, arz, as, ast, az, azb, ba, be, be...
# 19682  [en, af, als, an, ar, arz, az, ba, bar, be-x-o...
# 18218  [en, als, ar, arz, az, azb, ba, bar, be-x-old,...
# 18062  [en, af, als, ar, arz, as, az, azb, ba, bar, b...
# 20888  [en, af, als, ar, arz, as, az, azb, ba, be, be...
# 18918  [en, als, ar, arz, ast, az, azb, bar, be, be-x...
# 18203  [en, af, ar, arz, as, azb, ba, be, bg, bh, bn,...
# 19715  [en, ar, ary, ast, av, az, azb, bg, bn, br, bs...
# 21288  [en, ar, arz, as, az, azb, ba, be-x-old, bg, b...
# 22932  [en, ar, ary, arz, as, az, azb, ba, be, be-x-o...
# 20779  [en, als, ar, ary, arz, az, ba, bg, bn, ca, ck...
# 18937  [en, ar, arz, ba, bg, bn, ca, ckb, cs, da, de,...
# 22820  [en, af, ar, arz, as, bh, bn, ca, da, de, eo, ...
# 20931  [en, ar, arz, as, az, azb, ba, be, be-x-old, b...
# 18132  [en, af, ar, arz, ba, be, be-x-old, bg, bn, ca...
# 20732  [en, ar, as, ast, bn, ca, ckb, cs, da, de, dsb...
# 11496  [it, ar, ast, az, ba, be, be-x-old, bg, br, bs...
# 20508  [en, ar, ast, az, ba, be, be-x-old, bg, br, bs...
# 19638  [en, ak, ar, ary, arz, ast, az, bn, cdo, ckb, ...
# 18770  [en, als, ar, arz, as, azb, be, be-x-old, bg, ...
# 27047  [en, ar, az, ba, bn, cs, da, de, el, eo, es, f...
# 22583  [en, ar, ary, arz, az, azb, bh, cs, de, es, fa...
# 30449  [en, ar, as, az, azb, bn, br, ckb, de, el, es,...
# 5644   [es, ang, as, ast, ca, ceb, cs, da, de, en, eo...
# 20839  [en, af, ar, ca, cs, da, de, es, fa, fr, it, j...
# 27050  [en, ar, bg, br, chr, de, es, fa, fi, fr, hr, ...
# 20510  [en, bg, de, es, fa, fi, fr, gl, hu, id, it, j...
#
#                                                ill_links  \
# 27126  {'en': 'Wikipedia:Administrators', 'aa': 'Wiki...
# 18234  {'en': 'Wikipedia:Bots', 'ace': 'Wikipedia:Bot...
# 21865  {'en': 'Wikipedia:Requests for adminship', 'ab...
# 22561  {'en': 'Wikipedia:Stub', 'af': 'Wikipedia:Saad...
# 19284  {'en': 'Wikipedia:Five pillars', 'af': 'Wikipe...
# 18612  {'en': 'Wikipedia:Copyrights', 'ab': 'Авикипед...
# 20842  {'en': 'Wikipedia:Neutral point of view', 'af'...
# 27115  {'en': 'Wikipedia:What Wikipedia is not', 'af'...
# 18265  {'en': 'Wikipedia:Bureaucrats', 'af': 'Wikiped...
# 18748  {'en': 'Wikipedia:Disambiguation', 'af': 'Wiki...
# 20446  {'en': 'Wikipedia:Manual of Style', 'af': 'Wik...
# 21018  {'en': 'Wikipedia:Citing sources', 'af': 'Wiki...
# 17608  {'en': 'Wikipedia:Articles for deletion', 'ady...
# 21293  {'en': 'Wikipedia:Policies and guidelines', 'a...
# 26858  {'en': 'Wikipedia:Vandalism', 'af': 'Wikipedia...
# 17447  {'en': 'Wikipedia:Article titles', 'ab': 'Авик...
# 20907  {'en': 'Wikipedia:Notability', 'af': 'Wikipedi...
# 26734  {'en': 'Wikipedia:User pages', 'af': 'Wikipedi...
# 26863  {'en': 'Wikipedia:Verifiability', 'af': 'Wikip...
# 22460  {'en': 'Wikipedia:Signatures', 'als': 'Hilfe:S...
# 22581  {'en': 'Wikipedia:Protection policy', 'af': 'W...
# 18628  {'en': 'Wikipedia:Criteria for speedy deletion...
# 22454  {'en': 'Wikipedia:Shortcut', 'af': 'Wikipedia:...
# 22530  {'en': 'Wikipedia:Sockpuppetry', 'af': 'Wikipe...
# 18904  {'en': 'Wikipedia:Categorization', 'als': 'Wik...
# 18188  {'en': 'Wikipedia:Be bold', 'af': 'Wikipedia:V...
# 20884  {'en': 'Wikipedia:No original research', 'af':...
# 19670  {'en': 'Wikipedia:Ignore all rules', 'als': 'W...
# 18717  {'en': 'Wikipedia:Deletion policy', 'af': 'Wik...
# 19682  {'en': 'Wikipedia:Image use policy', 'af': 'Wi...
# 18218  {'en': 'Wikipedia:Blocking policy', 'als': 'Wi...
# 18062  {'en': 'Wikipedia:Assume good faith', 'af': 'W...
# 20888  {'en': 'Wikipedia:No personal attacks', 'af': ...
# 18918  {'en': 'Wikipedia:Etiquette', 'als': 'Wikipedi...
# 18203  {'en': 'Wikipedia:Biographies of living person...
# 19715  {'en': 'Wikipedia:Interface administrators', '...
# 21288  {'en': 'Wikipedia:Please do not bite the newco...
# 22932  {'en': 'Wikipedia:Edit warring', 'ar': 'ويكيبي...
# 20779  {'en': 'Wikipedia:Moving a page', 'als': 'Hilf...
# 18937  {'en': 'Wikipedia:External links', 'ar': 'ويكي...
# 22820  {'en': 'Wikipedia:Template documentation', 'af...
# 20931  {'en': 'Wikipedia:Notability (people)', 'ar': ...
# 18132  {'en': 'Wikipedia:Autobiography', 'af': 'Wikip...
# 20732  {'en': 'Wikipedia:Merging', 'ar': 'ويكيبيديا:د...
# 11496  {'it': 'Wikipedia:Evasività', 'ar': 'ويكيبيديا...
# 20508  {'en': 'Wikipedia:Manual of Style/Words to wat...
# 19638  {'en': 'Wikipedia:IP block exemption', 'ak': '...
# 18770  {'en': 'Wikipedia:Do not disrupt Wikipedia to ...
# 27047  {'en': 'Wikipedia:Volunteer Response Team', 'a...
# 22583  {'en': 'Wikipedia:Oversight', 'ar': 'ويكيبيديا...
# 30449  {'en': 'Wikipedia:Wikipedia is not a dictionar...
# 5644   {'es': 'Wikipedia:Esta página está protegida',...
# 20839  {'en': 'Wikipedia:Navigation template', 'af': ...
# 27050  {'en': 'Wikipedia:Polling is not a substitute ...
# 20510  {'en': 'Wikipedia:Manual of Style/Writing abou...
#
#                                                 en_title
# 27126                           Wikipedia:Administrators
# 18234                                     Wikipedia:Bots
# 21865                   Wikipedia:Requests for adminship
# 22561                                     Wikipedia:Stub
# 19284                             Wikipedia:Five pillars
# 18612                               Wikipedia:Copyrights
# 20842                    Wikipedia:Neutral point of view
# 27115                    Wikipedia:What Wikipedia is not
# 18265                              Wikipedia:Bureaucrats
# 18748                           Wikipedia:Disambiguation
# 20446                          Wikipedia:Manual of Style
# 21018                           Wikipedia:Citing sources
# 17608                    Wikipedia:Articles for deletion
# 21293                  Wikipedia:Policies and guidelines
# 26858                                Wikipedia:Vandalism
# 17447                           Wikipedia:Article titles
# 20907                               Wikipedia:Notability
# 26734                               Wikipedia:User pages
# 26863                            Wikipedia:Verifiability
# 22460                               Wikipedia:Signatures
# 22581                        Wikipedia:Protection policy
# 18628             Wikipedia:Criteria for speedy deletion
# 22454                                 Wikipedia:Shortcut
# 22530                             Wikipedia:Sockpuppetry
# 18904                           Wikipedia:Categorization
# 18188                                  Wikipedia:Be bold
# 20884                     Wikipedia:No original research
# 19670                         Wikipedia:Ignore all rules
# 18717                          Wikipedia:Deletion policy
# 19682                         Wikipedia:Image use policy
# 18218                          Wikipedia:Blocking policy
# 18062                        Wikipedia:Assume good faith
# 20888                      Wikipedia:No personal attacks
# 18918                                Wikipedia:Etiquette
# 18203            Wikipedia:Biographies of living persons
# 19715                 Wikipedia:Interface administrators
# 21288         Wikipedia:Please do not bite the newcomers
# 22932                             Wikipedia:Edit warring
# 20779                            Wikipedia:Moving a page
# 18937                           Wikipedia:External links
# 22820                   Wikipedia:Template documentation
# 20931                      Wikipedia:Notability (people)
# 18132                            Wikipedia:Autobiography
# 20732                                  Wikipedia:Merging
# 11496  Wikipedia:Manual of Style/Words to watch#Unsup...
# 20508           Wikipedia:Manual of Style/Words to watch
# 19638                       Wikipedia:IP block exemption
# 18770  Wikipedia:Do not disrupt Wikipedia to illustra...
# 27047                  Wikipedia:Volunteer Response Team
# 22583                                Wikipedia:Oversight
# 30449            Wikipedia:Wikipedia is not a dictionary
# 5644                            Wikipedia:Protected page
# 20839                      Wikipedia:Navigation template
# 27050  Wikipedia:Polling is not a substitute for disc...
# 20510    Wikipedia:Manual of Style/Writing about fiction
